# %% [markdown]
# *Auto-generated from a Mathcad worksheet by mcad2py.*

# %%
import math
import pint

from mcad2py.runtime import cos
ureg = pint.UnitRegistry()

# %% [markdown]
# slab:

# %%
t = 200 * ureg.mm

# %%
E_c = 30 * ureg.GPa

# %% [markdown]
# Soil stiffness

# %%
k = 5000 * (ureg.kPa / ureg.m)

# %% [markdown]
# Analytical solution of beam on elastic foundation as per Hetenyi "Beams of elastic foundation" 11th print, 1979

# %%
lambda_ = (3 * k / (E_c * t**3))**(1 / 4)
lambda_

# %% [markdown]
# char length:

# %%
lambda_**-1

# %% [markdown]
# shape functions:

# %%
Dx = math.exp(-lambda_ * x) * cos(lambda_ * x)

# %% [markdown]
# width of wall:

# %%
w = 300 * ureg.mm

# %% [markdown]
# unit load:

# %%
q = 1 * (ureg.kN / ureg.m) / w

# %% [markdown]
# deflection under wall:

# %%
a = w / 2

# %%
b = w / 2

# %%
y = q / (2 * k) * (2 - D(a) - D(b))
y.to(ureg.mm)

# %% [markdown]
# Eq: line spring:

# %%
K = 1 * (ureg.kN / ureg.m) / y
K.to(ureg.kN * ureg.m**-1 / ureg.m)
